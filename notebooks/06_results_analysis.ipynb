# %% [markdown]
# # Results Analysis
#
# This notebook compares Classical vs Quantum models using metrics and statistical tests.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os

# Add project root to path for imports
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.evaluation.metrics import calculate_metrics
from src.evaluation.cost_sensitive import calculate_financial_loss
from src.evaluation.statistical_tests import perform_ttest

# Example Resuls Loading (Placeholder)
results = {
    'XGBoost': {'accuracy': 0.99, 'f1': 0.85, 'loss': 5000},
    'VQNN': {'accuracy': 0.98, 'f1': 0.82, 'loss': 6000}
}
df_res = pd.DataFrame(results).T
df_res
# Out:
#          accuracy    f1    loss
# XGBoost      0.99  0.85  5000.0
# VQNN         0.98  0.82  6000.0

# %%
# Plotting
df_res[['f1', 'loss']].plot(kind='bar', subplots=True)
# Out:
# array([<Axes: title={'center': 'f1'}>, <Axes: title={'center': 'loss'}>],
#       dtype=object)
